# %% [markdown]
# # Ejercicio de Iteración de políticas

# %% [markdown]
# ## Instalar los requerimientos

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ------------------------------------ 925.5/925.5 kB 901.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 936.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 1.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 374.4/374.4 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 10.4/10.4 MB 1.1 MB/s eta 0:00:00
# ...
#      ------------------------------------ 172.3/172.3 MB 758.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.5/6.5 MB 652.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 663.0 kB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importar dependencias

# %%
import gymnasium as gym
import numpy as np
from plot_utils import plot_values

# %% [markdown]
# ## Para hacer: Arregla el código para desarrollar tu algoritmo de Iteración de Políticas

# %%
class PolicyIteration:
    def __init__(
        self, env: gym.Env, gamma: float, pi_error: float, pe_error: float
    ) -> None:
        self.env = env  # OpenAI gym environment
        self.gamma = gamma  # Discount factor
        self.pi_error = pi_error  # Policy improvement error
        self.pe_error = pe_error  # Policy evaluation error

    def train(self) -> tuple[np.ndarray, np.ndarray]:
        """
        Policy iteration algorithm.

        Returns:
            policy (np.ndarray): optimal policy
            Value  (np.ndarray): optimal value function
        """
        # TODO: Fix the code
        
        # Random policy
        policy = (
            np.ones([self.env.observation_space.n, self.env.action_space.n])
            / self.env.action_space.n
        )
        
        # Random value function
        V = np.zeros(self.env.observation_space.n)
        
        return policy, V

    def policy_evaluation(self, policy: np.ndarray) -> np.ndarray:
        """
        Policy evaluation.

        Args:
            policy (np.ndarray): policy to evaluate

        Returns:
            V (np.ndarray): value function
        """
        # TODO: Fix the code
        V = np.zeros(self.env.observation_space.n)
        
        return V

    def policy_improvement(self, V: np.ndarray) -> np.ndarray:
        """
        Policy improvement.

        Args:
            V (np.ndarray): value function

        Returns:
            policy (np.ndarray): improved policy
        """

        # TODO: Fix the code
        policy = np.zeros([self.env.observation_space.n, self.env.action_space.n])

        return policy

    def get_q_from_v(self, V: np.ndarray) -> np.ndarray:
        """
        Get the Q values from the value function.

        Args:
            V (np.ndarray): Value function

        Returns:
            Q (np.ndarray): Action-value function
        """
        # TODO: Fix the code
        Q = np.zeros([self.env.observation_space.n, self.env.action_space.n])
        
        return Q

    def play(self, policy: np.ndarray, render: bool = True) -> float:
        """
        Play with the given policy.

        Args:
            policy (np.ndarray): policy to play with
            render (bool): whether to render the game or not

        Returns:
            total_reward (float): total reward achieved in this episode
        """
        total_reward = 0.0
        state, _ = self.env.reset()
        while True:
            if render:
                self.env.render()
            action = np.argmax(policy[state])
            state, reward, done, _, _ = self.env.step(action)
            total_reward += reward
            if done:
                break
        return total_reward

# %% [markdown]
# ## Observa a tu agente jugar

# %%
size = 4  # Only 4 and 8 are supported
env = gym.make(
    "FrozenLake-v1",
    desc=None,
    map_name=f"{size}x{size}",
    is_slippery=False,
    render_mode="human",
)
gamma: float = 0.9
pi_error: float = 1e-10
pe_error: float = 1e-8

# Run policy iteration
policy_iteration = PolicyIteration(env, gamma, pi_error, pe_error)
policy, V = policy_iteration.train()

policy_iteration.play(policy)

plot_values(V, size)

# %% [markdown]
# ## Verifica que tu solución sea correcta

# %% [markdown]
# ## Responde a estas preguntas
#
# 1. ¿Qué sucede cuando configuras tu entorno con is_slippery=True? ¿Cuál es el efecto en la función de valor? ¿Por qué?
# 2. ¿Qué sucede con la función de valor cuando cambiamos gamma? ¿Por qué?
